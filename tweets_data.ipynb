# %%
import pandas as pd

file_path = 'dataset/847_capstone.csv'

df = pd.read_csv(file_path, engine='python')

# %% [markdown]
# ### Run the cell below to view data

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df.head(n=20)
# Out:
#     screen_name  \
# 0   JohnBoozman
# 1   JohnBoozman
# 2   JohnBoozman
# 3   JohnBoozman
# 4   JohnBoozman
# 5   JohnBoozman
# 6   JohnBoozman
# 7   JohnBoozman
# 8   JohnBoozman
# 9   JohnBoozman
# 10  JohnBoozman
# 11    JeffFlake
# 12  JohnBoozman
# 13  JohnBoozman
# 14  JohnBoozman
# 15  JohnBoozman
# 16  JohnBoozman
# 17  JohnBoozman
# 18  JohnBoozman
# 19    JeffFlake
#
#                                                                                                                                           text  \
# 0                                                                   On a conference call about a weekend trip to Iraq to visit Arkansas troops
# 1                                                                                                                    Being interviewed by KTHV
# 2                                                                            Being interviewed by KARN on his Arkansas World Trade Center trip
# ...

# %%
df['truncated'].value_counts()
# Out:
# truncated
# False    1243342
# Name: count, dtype: int64

# %%
twitter_handles = df['screen_name'].unique()
twitter_handles

th_df = pd.DataFrame(twitter_handles, columns=['twitter_handles'])

path = "dataset/twitter_handles.csv"
th_df.to_csv(path, index=False)

# %%
import pandas as pd

file_path = '847_capstone.csv'

df = pd.read_csv(file_path, engine='python')

df.head(n=50)
# Out:
#       screen_name                                               text truncated
# 0     JohnBoozman  On a conference call about a weekend trip to I...     False
# 1     JohnBoozman                          Being interviewed by KTHV     False
# 2     JohnBoozman  Being interviewed by KARN on his Arkansas Worl...     False
# 3     JohnBoozman              On KWHN in Fort Smith, that's 1320 AM     False
# 4     JohnBoozman  Attending a Military of the Purple Heart Cerem...     False
# 5     JohnBoozman      Touring Helath South Hospital in Fayetteville     False
# 6     JohnBoozman  conducting a veterans affairs economic opportu...     False
# 7     JohnBoozman                   doing an interview on kurm radio     False
# 8     JohnBoozman  Meeting with Emergency Management officials fr...     False
# 9     JohnBoozman  Listening to constituents at a roundtable disc...     False
# 10    JohnBoozman                       attending the GOP convention     False
# ...
